# %% [markdown]
# # **Cuaderno de ETL: De Datos Abiertos a un Modelo de Estrella**
#
# **Objetivo:** Tomar un conjunto de datos públicos sobre estadísticas de educación en Colombia y transformarlo en un modelo dimensional de estrella, listo para ser analizado con herramientas de Business Intelligence.
#
# **Fuente de Datos:** [MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR-B-SICA](https://www.datos.gov.co/Educaci-n/MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR-B-SICA/nudc-7mev/about_data)
#
# **Nuestro Modelo de Estrella a Construir:**
#
# * **Tabla de Hechos (Fact_Matriculas):**
#     * `id_tiempo` (FK)
#     * `id_geografia` (FK)
#     * `total_matriculados` (Métrica)
#     ...
#
# * **Tablas de Dimensiones:**
#     * `Dim_Tiempo` (año)
#     * `Dim_Geografia` (departamento, municipio)
#
# ¡Manos a la obra!

# %%
# ===================================================================
# PASO 1: CONFIGURACIÓN E INSTALACIÓN DE LIBRERÍAS
# ===================================================================

import pandas as pd
import requests
import sqlite3

print("✅ Librerías importadas.")

# ===================================================================
# PASO 2: EXTRACCIÓN (EXTRACT) DE LOS DATOS
# ===================================================================

# La plataforma datos.gov.co usa la API de Socrata. Podemos usarla para
# descargar los datos directamente, lo que es más eficiente que bajar un CSV.
# Aumentamos el límite para traer más filas (ajusta si es necesario).
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"

print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# ✅ Librerías importadas.
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ❌ Error al extraer los datos: HTTPSConnectionPool(host='www.datos.gov.co', port=443): Max retries exceeded with url: /resource/nudc-7mev.json?$limit=50000 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000129411B2450>: Failed to resolve 'www.datos.gov.co' ([Errno 11001] getaddrinfo failed)"))

# %%
df_raw
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## **3. Transformación (Transform)**
#
# Esta es la fase más importante. Aquí limpiamos los datos crudos y los moldeamos para que encajen en nuestro modelo de estrella.
#
# **Pasos:**
# 1.  **Limpieza y Preparación:** Convertiremos las columnas a los tipos de datos correctos y manejaremos valores faltantes. La columna `matricula` es nuestra métrica principal.
# 2.  **Creación de Dimensiones:** A partir del DataFrame limpio, crearemos una tabla (DataFrame) para cada dimensión, asegurándonos de que no tengan filas duplicadas y asignando una **llave subrogada** (un ID numérico único).
# 3.  **Creación de la Tabla de Hechos:** Construiremos la tabla de hechos, que contendrá nuestra métrica (`total_matriculados`) y las llaves foráneas que la conectan a cada dimensión.

# %% [markdown]
# ## Solución
#
# 1. *Limpieza y Preparación*

# %%
df_raw.columns = [col.lower() for col in df_raw.columns]

# %%
df_raw.columns = df_raw.columns.str.lower()

# %%
print(df_raw.columns.tolist())
# Out:
# []

# %%
df_raw.isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
print(df_raw.dtypes)
# Out:
# Series([], dtype: object)

# %%
columnas_numericas = [
    'poblaci_n_5_16', 'tasa_matriculaci_n_5_16', 'cobertura_neta',
    'cobertura_neta_transici_n', 'cobertura_neta_primaria', 'cobertura_neta_secundaria',
    'cobertura_neta_media', 'cobertura_bruta', 'cobertura_bruta_transici_n',
    'cobertura_bruta_primaria', 'cobertura_bruta_secundaria', 'cobertura_bruta_media',
    'deserci_n', 'deserci_n_transici_n', 'deserci_n_primaria', 'deserci_n_secundaria',
    'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria',
    'aprobaci_n_secundaria', 'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n',
    'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media',
    'repitencia', 'repitencia_transici_n', 'repitencia_primaria', 'repitencia_secundaria',
    'repitencia_media', 'tama_o_promedio_de_grupo', 'sedes_conectadas_a_internet'
]

# Convertir esas columnas a tipo numérico
for col in columnas_numericas:
    df_raw[col] = pd.to_numeric(df_raw[col], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Usuario\miniconda3\envs\diplomado_usta\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'poblaci_n_5_16'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 16
#      14 # Convertir esas columnas a tipo numérico
#      15 for col in columnas_numericas:
# ---> 16     df_raw[col] = pd.to_numeric(df_raw[col], errors='coerce')
#
# File c:\Users\Usuario\miniconda3\envs\diplomado_usta\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\Usuario\miniconda3\envs\diplomado_usta\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'poblaci_n_5_16'

# %%
#Se relleno los datos nulos con la media para mantener la estructura de la base de datos 
df_raw[columnas_numericas] = df_raw[columnas_numericas].fillna(df_raw[columnas_numericas].mean())

# %%
print("Años únicos:", df_raw['a_o'].unique())
print("Departamentos únicos:", df_raw['departamento'].nunique())
print("Municipios únicos:", df_raw['municipio'].nunique())
# Out:
# Años únicos: ['2023' '2022' '2021' '2020' '2019' '2018' '2017' '2016' '2015' '2014'
#  '2013' '2012' '2011']
# Departamentos únicos: 36
# Municipios únicos: 1037

# %%
dept_check = df_raw[['c_digo_departamento', 'departamento']].drop_duplicates()
dept_group = dept_check.groupby('c_digo_departamento').agg({'departamento': pd.Series.nunique})
conflictos = dept_group[dept_group['departamento'] > 1]

print(conflictos)

# Error nombre
nombres_conflictivos = df_raw[df_raw['c_digo_departamento'].isin(conflictos.index)][['c_digo_departamento', 'departamento']].drop_duplicates()
print(nombres_conflictivos)
# Out:
#                      departamento
# c_digo_departamento
# 11                              2
# 88                              2
#      c_digo_departamento                                       departamento
# 32                    88  Archipiélago de San Andrés, Providencia y Sant...
# 974                   11                                       Bogotá, D.C.
# 3389                  88  Archipiélago de San Andrés. Providencia y Sant...
# 3653                  11                                        Bogotá D.C.

# %%
conflictos_municipio = (
    df_raw.groupby('c_digo_municipio')[['municipio', 'c_digo_departamento']]
    .nunique()
    .query('municipio > 1 or c_digo_departamento > 1')
)

print(conflictos_municipio)
# Out:
#                   municipio  c_digo_departamento
# c_digo_municipio
# 11001                     2                    1

# %%
df_raw['departamento'] = df_raw['departamento'].replace({
    'Bogotá D.C.': 'Bogotá, D.C.',
    'Archipiélago de San Andrés. Providencia y Santa Catalina.': 'Archipiélago de San Andrés, Providencia y Santa Catalina'
})

# %%
df_raw.loc[df_raw['c_digo_departamento'] == 88, 'departamento'] = \
    "Archipiélago de San Andrés, Providencia y Santa Catalina"

# %%
df_raw['departamento'] = df_raw['departamento'].str.strip().str.replace(r'[.,;]+', '', regex=True)

# %%
df_raw['municipio'] = df_raw['municipio'].str.strip().str.replace(r'[.,]', '', regex=True)

# %% [markdown]
# Cargue Divipola

# %%
import pandas as pd

url = "https://www.datos.gov.co/api/views/gdxc-w37w/rows.csv?accessType=DOWNLOAD"
divipola = pd.read_csv(url)

divipola.head()
# Out:
#    Código Departamento Nombre Departamento  Código Municipio Nombre Municipio  \
# 0                    5           ANTIOQUIA              5001         MEDELLÍN
# 1                    5           ANTIOQUIA              5002        ABEJORRAL
# 2                    5           ANTIOQUIA              5004         ABRIAQUÍ
# 3                    5           ANTIOQUIA              5021       ALEJANDRÍA
# 4                    5           ANTIOQUIA              5030            AMAGÁ
#
#   Tipo: Municipio / Isla / Área no municipalizada    longitud   Latitud
# 0                                       Municipio  -75,581775  6,246631
# 1                                       Municipio  -75,428739  5,789315
# 2                                       Municipio  -76,064304  6,632282
# 3                                       Municipio  -75,141346  6,376061
# 4                                       Municipio  -75,702188  6,038708

# %%
print(divipola.columns)
# Out:
# Index(['Código Departamento', 'Nombre Departamento', 'Código Municipio',
#        'Nombre Municipio', 'Tipo: Municipio / Isla / Área no municipalizada',
#        'longitud', 'Latitud'],
#       dtype='object')

# %%
divipola = divipola.rename(columns={
    'Código Departamento': 'c_digo_departamento',
    'Nombre Departamento': 'departamento',
    'Código Municipio': 'c_digo_municipio',
    'Nombre Municipio': 'municipio',
    'Tipo: Municipio / Isla / Área no municipalizada': 'tipo_territorial',
    'longitud': 'longitud',
    'Latitud': 'latitud'
})

# %% [markdown]
# 2. *Creación de Dimensiones*

# %%
# Convertir a numérico forzando errores como NaN
for col in ['c_digo_departamento', 'c_digo_municipio', 'c_digo_etc']:
    df_raw[col] = pd.to_numeric(df_raw[col], errors='coerce')

# Eliminar filas con valores faltantes
df_raw = df_raw.dropna(subset=['c_digo_departamento', 'c_digo_municipio', 'c_digo_etc'])

# Convertir a enteros
df_raw['c_digo_departamento'] = df_raw['c_digo_departamento'].astype(int)
df_raw['c_digo_municipio'] = df_raw['c_digo_municipio'].astype(int)
df_raw['c_digo_etc'] = df_raw['c_digo_etc'].astype(int)

# %%
dim_departamento = df_raw[['c_digo_departamento', 'departamento']].drop_duplicates()

dim_departamento = dim_departamento.merge(
    divipola[['c_digo_departamento', 'departamento']].drop_duplicates(),
    on='c_digo_departamento', how='left', suffixes=('', '_divipola')
)

dim_departamento = dim_departamento.reset_index(drop=True)
dim_departamento['id_departamento'] = dim_departamento.index + 1
dim_departamento = dim_departamento[['id_departamento', 'c_digo_departamento', 'departamento']]

# Validación
assert dim_departamento['c_digo_departamento'].is_unique, "Claves duplicadas en dim_departamento"
print("dim_departamento generada correctamente.")
# Out:
# dim_departamento generada correctamente.

# %%
dim_municipio = df_raw[['c_digo_municipio', 'c_digo_departamento']].drop_duplicates()

dim_municipio = dim_municipio.merge(
    divipola[['c_digo_municipio', 'municipio', 'tipo_territorial', 'latitud', 'longitud']],
    on='c_digo_municipio', how='left'
)

dim_municipio = dim_municipio.reset_index(drop=True)
dim_municipio['id_municipio'] = dim_municipio.index + 1

dim_municipio = dim_municipio[['id_municipio', 'c_digo_municipio', 'c_digo_departamento',
                               'municipio', 'tipo_territorial', 'latitud', 'longitud']]

# Validación
assert dim_municipio['c_digo_municipio'].is_unique, "Claves duplicadas en dim_municipio"
print("dim_municipio generada correctamente.")
# Out:
# dim_municipio generada correctamente.

# %%
dim_tiempo = df_raw[['a_o']].drop_duplicates().reset_index(drop=True)
dim_tiempo['id_tiempo'] = dim_tiempo.index + 1
dim_tiempo = dim_tiempo[['id_tiempo', 'a_o']]

# Validación
assert dim_tiempo['a_o'].is_unique, "Años duplicados en dim_tiempo"
print("dim_tiempo generada correctamente.")
# Out:
# dim_tiempo generada correctamente.

# %% [markdown]
# 3. *Creación de la tabla de Hechos*

# %%
df_hechos = df_raw.copy()

df_hechos = df_hechos.merge(
    dim_departamento[['id_departamento', 'c_digo_departamento']],
    on='c_digo_departamento', how='left'
)

df_hechos = df_hechos.merge(
    dim_municipio[['id_municipio', 'c_digo_municipio']],
    on='c_digo_municipio', how='left'
)

df_hechos = df_hechos.merge(
    dim_tiempo[['id_tiempo', 'a_o']],
    on='a_o', how='left'
)

# %%
columnas_medidas = [
    'tasa_matriculaci_n_5_16', 'cobertura_neta',
    'reprobaci_n_primaria', 'reprobaci_n_secundaria',
    'reprobaci_n_media', 'repitencia'
]

hechos_final = df_hechos[['id_departamento', 'id_municipio', 'id_tiempo'] + columnas_medidas]

print(" Tabla de hechos generada")
# Out:
#  Tabla de hechos generada

# %%
hechos_final.isnull().sum()
# Out:
# id_departamento            0
# id_municipio               0
# id_tiempo                  0
# tasa_matriculaci_n_5_16    0
# cobertura_neta             0
# reprobaci_n_primaria       0
# reprobaci_n_secundaria     0
# reprobaci_n_media          0
# repitencia                 0
# dtype: int64

# %%
hechos_final.describe()
# Out:
#        id_departamento  id_municipio     id_tiempo  tasa_matriculaci_n_5_16  \
# count     14585.000000  14585.000000  14585.000000             14585.000000
# mean         18.615632    561.462187      7.000617                84.971929
# std           9.417836    323.883394      3.741392                18.515676
# min           1.000000      1.000000      1.000000                 0.000000
# 25%          12.000000    281.000000      4.000000                74.940000
# 50%          20.000000    561.000000      7.000000                85.200000
# 75%          26.000000    842.000000     10.000000                95.300000
# max          34.000000   1123.000000     13.000000               279.030000
#
#        cobertura_neta  reprobaci_n_primaria  reprobaci_n_secundaria  \
# count    14585.000000           14585.00000            14585.000000
# mean        85.553196               3.88477                6.809006
# std         16.867791               3.78979                6.131056
# min          0.000000               0.00000                0.000000
# 25%         76.950000               0.43000                0.760000
# 50%         86.270000               3.38000                6.210000
# 75%         94.470000               5.98000               10.790000
# max        264.540000              51.97000               76.970000
#
#        reprobaci_n_media    repitencia
# count       14585.000000  14585.000000
# mean            4.130812      3.299480
# std             4.190776      3.353208
# min             0.000000      0.000000
# 25%             0.680000      0.730000
# 50%             3.160000      2.190000
# 75%             6.360000      5.040000
# max            67.860000     37.470000

# %%
hechos_final.head()
# Out:
#    id_departamento  id_municipio  id_tiempo  tasa_matriculaci_n_5_16  \
# 0                1             1          1                    62.62
# 1                2             2          1                    53.27
# 2                2             3          1                    32.52
# 3                3             4          1                    59.57
# 4                3             5          1                    51.30
#
#    cobertura_neta  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0           62.62                  1.96                   16.51
# 1           53.27                  7.11                    9.39
# 2           32.52                  6.93                   14.13
# 3           59.57                  4.04                    8.33
# 4           51.30                  7.32                   15.28
#
#    reprobaci_n_media  repitencia
# 0               2.04        9.52
# 1               1.75        9.34
# 2               7.81        8.65
# 3               4.60       16.18
# 4               7.27        9.24

# %%
hechos_nombres = hechos_final.copy()

hechos_nombres = hechos_nombres.merge(
    dim_municipio[['id_municipio', 'municipio']],
    on='id_municipio', how='left'
)

hechos_nombres = hechos_nombres.merge(
    dim_departamento[['id_departamento', 'departamento']],
    on='id_departamento', how='left'
)


hechos_nombres = hechos_nombres.merge(
    dim_tiempo[['id_tiempo', 'a_o']],  
    on='id_tiempo', how='left'
)

# %%
hechos_nombres.head()
# Out:
#    id_departamento  id_municipio  id_tiempo  tasa_matriculaci_n_5_16  \
# 0                1             1          1                    62.62
# 1                2             2          1                    53.27
# 2                2             3          1                    32.52
# 3                3             4          1                    59.57
# 4                3             5          1                    51.30
#
#    cobertura_neta  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0           62.62                  1.96                   16.51
# 1           53.27                  7.11                    9.39
# 2           32.52                  6.93                   14.13
# 3           59.57                  4.04                    8.33
# 4           51.30                  7.32                   15.28
#
#    reprobaci_n_media  repitencia   municipio departamento   a_o
# 0               2.04        9.52    ABRIAQUÍ    Antioquia  2023
# 1               1.75        9.34  EL RETORNO     Guaviare  2023
# 2               7.81        8.65  MIRAFLORES     Guaviare  2023
# 3               4.60       16.18        MITÚ       Vaupés  2023
# 4               7.27        9.24      CARURÚ       Vaupés  2023

# %% [markdown]
# ## Preguntas
#
# 1. Respecto a la población del municipio ¿Que porcentaje de escolaridad hay?
#
# 2. ¿Cómo compararía el rendimiento educativo por municipios?
#
# 3. ¿Que departamentos son los que mejor cobertura tienen? ¿Pueden hacer cálculo con SQL?

# %% [markdown]
# Este ejercicio se entrega en un archivo Jupyter Notebook (.ipynb) que contenga el código necesario para realizar las consultas en SQL y que previamente haya creado la bodega de datos con un modelo dimensional adecuado.

# %% [markdown]
# ####  Porcentaje de escolaridad por municipio

# %%
porcentaje_escolaridad = hechos_nombres.groupby(['departamento', 'municipio'])['tasa_matriculaci_n_5_16'].mean().reset_index()
porcentaje_escolaridad = porcentaje_escolaridad.rename(columns={'tasa_matriculaci_n_5_16': 'porcentaje_escolaridad'})
porcentaje_escolaridad = porcentaje_escolaridad.sort_values(by='porcentaje_escolaridad', ascending=False)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

porcentaje_escolaridad
# Out:
#                                            departamento  \
# 517                                        Cundinamarca
# 158                                           Atlántico
# 545                                        Cundinamarca
# 894                                             Quindio
# 592                                        Cundinamarca
# 528                                        Cundinamarca
# 584                                        Cundinamarca
# 970                                           Santander
# 601                                        Cundinamarca
# 451                                               Cesar
# 952                                           Santander
# 767                                              Nariño
# 748                                                Meta
# 978                                           Santander
# 312                                              Boyacá
# 841                                  Norte de Santander
# 754                                                Meta
# 835                                  Norte de Santander
# 445                                               Cesar
# 77                                            Antioquia
# 279                                              Boyacá
# 914                                           Santander
# 455                                               Cesar
# 97                                            Antioquia
# 959                                           Santander
# 892                                             Quindio
# 758                                                Meta
# 448                                               Cesar
# 480                                               Chocó
# 713                                           Magdalena
# 128                                           Antioquia
# 975                                           Santander
# 739                                                Meta
# 64                                            Antioquia
# 555                                        Cundinamarca
# 329                                              Boyacá
# 999                                               Sucre
# 94                                            Antioquia
# 679                                               Huila
# 449                                               Cesar
# 309                                              Boyacá
# 962                                           Santander
# 541                                        Cundinamarca
# 331                                              Boyacá
# 59                                            Antioquia
# 740                                                Meta
# 1047                                             Tolima
# 729                                           Magdalena
# 738                                                Meta
# 697                                          La Guajira
# 389                                            Casanare
# 467                                               Chocó
# 728                                           Magdalena
# 865                                  Norte de Santander
# 1054                                             Tolima
# 385                                            Casanare
# 73                                            Antioquia
# 278                                              Boyacá
# 737                                                Meta
# 470                                               Chocó
# 307                                              Boyacá
# 398                                            Casanare
# 443                                               Cesar
# 1119                                            Vichada
# 58                                            Antioquia
# 717                                           Magdalena
# 306                                              Boyacá
# 1006                                              Sucre
# 525                                        Cundinamarca
# 180                                             Bolívar
# 4                                              Amazonas
# 722                                           Magdalena
# 473                                               Chocó
# 54                                            Antioquia
# 742                                                Meta
# 105                                           Antioquia
# 736                                           Magdalena
# 1058                                             Tolima
# 995                                           Santander
# 107                                           Antioquia
# 250                                              Boyacá
# 564                                        Cundinamarca
# 114                                           Antioquia
# 703                                          La Guajira
# 500                                        Cundinamarca
# 1007                                              Sucre
# 463                                               Cesar
# 407                                               Cauca
# 1009                                              Sucre
# 471                                               Chocó
# 425                                               Cauca
# 1000                                              Sucre
# 942                                           Santander
# 52                                            Antioquia
# 744                                                Meta
# 1018                                              Sucre
# 178                                             Bolívar
# 130                                           Antioquia
# 399                                            Casanare
# 465                                               Cesar
# 734                                           Magdalena
# 747                                                Meta
# 108                                           Antioquia
# 876                                            Putumayo
# 880                                            Putumayo
# 1029                                             Tolima
# 515                                        Cundinamarca
# 135                                           Antioquia
# 218                                              Boyacá
# 759                                                Meta
# 93                                            Antioquia
# 905                                           Risaralda
# 727                                           Magdalena
# 44                                            Antioquia
# 608                                        Cundinamarca
# 345                                              Caldas
# 284                                              Boyacá
# 535                                        Cundinamarca
# 904                                           Risaralda
# 456                                               Cesar
# 79                                            Antioquia
# 838                                  Norte de Santander
# 390                                            Casanare
# 924                                           Santander
# 939                                           Santander
# 1013                                              Sucre
# 177                                             Bolívar
# 198                                             Bolívar
# 47                                            Antioquia
# 153                                           Atlántico
# 74                                            Antioquia
# 569                                        Cundinamarca
# 756                                                Meta
# 304                                              Boyacá
# 1086                                    Valle del Cauca
# 13                                            Antioquia
# 917                                           Santander
# 169                                             Bolívar
# 976                                           Santander
# 388                                            Casanare
# 253                                              Boyacá
# 714                                           Magdalena
# 330                                              Boyacá
# 447                                               Cesar
# 461                                               Cesar
# 277                                              Boyacá
# 882                                            Putumayo
# 1062                                             Tolima
# 790                                              Nariño
# 450                                               Cesar
# 549                                        Cundinamarca
# 395                                            Casanare
# 1011                                              Sucre
# 607                                        Cundinamarca
# 719                                           Magdalena
# 113                                           Antioquia
# 392                                            Casanare
# 604                                        Cundinamarca
# 146                                           Atlántico
# 204                                             Bolívar
# 38                                            Antioquia
# 720                                           Magdalena
# 488                                               Chocó
# 750                                                Meta
# 474                                               Chocó
# 633                                             Córdoba
# 1020                                              Sucre
# 577                                        Cundinamarca
# 165                                           Atlántico
# 716                                           Magdalena
# 871                                            Putumayo
# 991                                           Santander
# 678                                               Huila
# 522                                        Cundinamarca
# 972                                           Santander
# 628                                             Córdoba
# 937                                           Santander
# 513                                        Cundinamarca
# 245                                              Boyacá
# 700                                          La Guajira
# 596                                        Cundinamarca
# 494                                               Chocó
# 200                                             Bolívar
# 426                                               Cauca
# 671                                               Huila
# 707                                           Magdalena
# 626                                             Córdoba
# 1001                                              Sucre
# 85                                            Antioquia
# 949                                           Santander
# 499                                        Cundinamarca
# 82                                            Antioquia
# 520                                        Cundinamarca
# 711                                           Magdalena
# 1088                                    Valle del Cauca
# 209                                             Bolívar
# 362                                              Caldas
# 1005                                              Sucre
# 142                                              Arauca
# 810                                              Nariño
# 154                                           Atlántico
# 175                                             Bolívar
# 986                                           Santander
# 618                                             Córdoba
# 336                                              Boyacá
# 989                                           Santander
# 616                                             Córdoba
# 968                                           Santander
# 1078                                    Valle del Cauca
# 709                                           Magdalena
# 1044                                             Tolima
# 211                                             Bolívar
# 967                                           Santander
# 45                                            Antioquia
# 1045                                             Tolima
# 357                                              Caldas
# 67                                            Antioquia
# 993                                           Santander
# 1096                                    Valle del Cauca
# 889                                             Quindio
# 565                                        Cundinamarca
# 1068                                             Tolima
# 533                                        Cundinamarca
# 1090                                    Valle del Cauca
# 901                                           Risaralda
# 1046                                             Tolima
# 712                                           Magdalena
# 1036                                             Tolima
# 645                                             Guainía
# 122                                           Antioquia
# 640                                             Córdoba
# 798                                              Nariño
# 981                                           Santander
# 1109                                    Valle del Cauca
# 718                                           Magdalena
# 526                                        Cundinamarca
# 1037                                             Tolima
# 508                                        Cundinamarca
# 239                                              Boyacá
# 432                                               Cauca
# 1035                                             Tolima
# 383                                            Casanare
# 464                                               Cesar
# 860                                  Norte de Santander
# 201                                             Bolívar
# 622                                             Córdoba
# 687                                               Huila
# 745                                                Meta
# 987                                           Santander
# 76                                            Antioquia
# 195                                             Bolívar
# 677                                               Huila
# 1082                                    Valle del Cauca
# 958                                           Santander
# 292                                              Boyacá
# 185                                             Bolívar
# 1017                                              Sucre
# 174                                             Bolívar
# 386                                            Casanare
# 106                                           Antioquia
# 1026                                             Tolima
# 203                                             Bolívar
# 842                                  Norte de Santander
# 99                                            Antioquia
# 81                                            Antioquia
# 643                                             Guainía
# 1043                                             Tolima
# 912                                           Santander
# 887                                             Quindio
# 31                                            Antioquia
# 112                                           Antioquia
# 625                                             Córdoba
# 732                                           Magdalena
# 145                                           Atlántico
# 764                                                Meta
# 552                                        Cundinamarca
# 632                                             Córdoba
# 537                                        Cundinamarca
# 615                                             Córdoba
# 1014                                              Sucre
# 920                                           Santander
# 1085                                    Valle del Cauca
# 186                                             Bolívar
# 160                                           Atlántico
# 974                                           Santander
# 421                                               Cauca
# 334                                              Boyacá
# 813                                              Nariño
# 620                                             Córdoba
# 1021                                              Sucre
# 599                                        Cundinamarca
# 75                                            Antioquia
# 84                                            Antioquia
# 101                                           Antioquia
# 1080                                    Valle del Cauca
# 1098                                    Valle del Cauca
# 1031                                             Tolima
# 606                                        Cundinamarca
# 406                                               Cauca
# 519                                        Cundinamarca
# 1097                                    Valle del Cauca
# 997                                               Sucre
# 683                                               Huila
# 100                                           Antioquia
# 655                                               Huila
# 371                                             Caquetá
# 27                                            Antioquia
# 1016                                              Sucre
# 588                                        Cundinamarca
# 923                                           Santander
# 261                                              Boyacá
# 1060                                             Tolima
# 672                                               Huila
# 104                                           Antioquia
# 1033                                             Tolima
# 176                                             Bolívar
# 1039                                             Tolima
# 184                                             Bolívar
# 123                                           Antioquia
# 788                                              Nariño
# 780                                              Nariño
# 78                                            Antioquia
# 1077                                    Valle del Cauca
# 109                                           Antioquia
# 437                                               Cauca
# 911                                           Santander
# 301                                              Boyacá
# 557                                        Cundinamarca
# 583                                        Cundinamarca
# 327                                              Boyacá
# 281                                              Boyacá
# 551                                        Cundinamarca
# 214                                             Bolívar
# 269                                              Boyacá
# 401                                               Cauca
# 723                                           Magdalena
# 285                                              Boyacá
# 147                                           Atlántico
# 95                                            Antioquia
# 458                                               Cesar
# 417                                               Cauca
# 635                                             Córdoba
# 503                                        Cundinamarca
# 217                                              Boyacá
# 191                                             Bolívar
# 998                                               Sucre
# 237                                              Boyacá
# 863                                  Norte de Santander
# 726                                           Magdalena
# 454                                               Cesar
# 741                                                Meta
# 945                                           Santander
# 459                                               Cesar
# 675                                               Huila
# 922                                           Santander
# 188                                             Bolívar
# 1094                                    Valle del Cauca
# 308                                              Boyacá
# 915                                           Santander
# 792                                              Nariño
# 326                                              Boyacá
# 352                                              Caldas
# 1083                                    Valle del Cauca
# 1012                                              Sucre
# 866                                  Norte de Santander
# 1003                                              Sucre
# 808                                              Nariño
# 1092                                    Valle del Cauca
# 72                                            Antioquia
# 985                                           Santander
# 721                                           Magdalena
# 546                                        Cundinamarca
# 423                                               Cauca
# 873                                            Putumayo
# 839                                  Norte de Santander
# 540                                        Cundinamarca
# 364                                              Caldas
# 735                                           Magdalena
# 956                                           Santander
# 667                                               Huila
# 213                                             Bolívar
# 110                                           Antioquia
# 1027                                             Tolima
# 996                                               Sucre
# 1075                                    Valle del Cauca
# 762                                                Meta
# 960                                           Santander
# 442                                               Cesar
# 812                                              Nariño
# 210                                             Bolívar
# 852                                  Norte de Santander
# 611                                        Cundinamarca
# 676                                               Huila
# 117                                           Antioquia
# 323                                              Boyacá
# 710                                           Magdalena
# 859                                  Norte de Santander
# 746                                                Meta
# 743                                                Meta
# 590                                        Cundinamarca
# 88                                            Antioquia
# 295                                              Boyacá
# 979                                           Santander
# 884                                             Quindio
# 1063                                             Tolima
# 288                                              Boyacá
# 624                                             Córdoba
# 582                                        Cundinamarca
# 324                                              Boyacá
# 381                                            Casanare
# 446                                               Cesar
# 857                                  Norte de Santander
# 92                                            Antioquia
# 614                                             Córdoba
# 42                                            Antioquia
# 420                                               Cauca
# 348                                              Caldas
# 410                                               Cauca
# 302                                              Boyacá
# 230                                              Boyacá
# 940                                           Santander
# 1040                                             Tolima
# 148                                           Atlántico
# 151                                           Atlántico
# 1073                                    Valle del Cauca
# 1028                                             Tolima
# 883                                             Quindio
# 150                                           Atlántico
# 926                                           Santander
# 497                                        Cundinamarca
# 116                                           Antioquia
# 957                                           Santander
# 129                                           Antioquia
# 1059                                             Tolima
# 121                                           Antioquia
# 415                                               Cauca
# 1053                                             Tolima
# 1019                                              Sucre
# 642                                             Córdoba
# 638                                             Córdoba
# 769                                              Nariño
# 684                                               Huila
# 681                                               Huila
# 134                                           Antioquia
# 466                                               Cesar
# 674                                               Huila
# 55                                            Antioquia
# 809                                              Nariño
# 983                                           Santander
# 305                                              Boyacá
# 1042                                             Tolima
# 70                                            Antioquia
# 907                                           Risaralda
# 613                                             Córdoba
# 619                                             Córdoba
# 296                                              Boyacá
# 49                                            Antioquia
# 950                                           Santander
# 61                                            Antioquia
# 260                                              Boyacá
# 444                                               Cesar
# 69                                            Antioquia
# 181                                             Bolívar
# 793                                              Nariño
# 268                                              Boyacá
# 691                                               Huila
# 340                                              Caldas
# 482                                               Chocó
# 332                                              Boyacá
# 187                                             Bolívar
# 481                                               Chocó
# 33                                            Antioquia
# 893                                             Quindio
# 216                                              Boyacá
# 579                                        Cundinamarca
# 1002                                              Sucre
# 669                                               Huila
# 668                                               Huila
# 168                                           Bogotá DC
# 828                                              Nariño
# 656                                               Huila
# 409                                               Cauca
# 1004                                              Sucre
# 637                                             Córdoba
# 37                                            Antioquia
# 573                                        Cundinamarca
# 670                                               Huila
# 561                                        Cundinamarca
# 1104                                    Valle del Cauca
# 397                                            Casanare
# 847                                  Norte de Santander
# 658                                               Huila
# 29                                            Antioquia
# 1057                                             Tolima
# 1034                                             Tolima
# 102                                           Antioquia
# 562                                        Cundinamarca
# 706                                          La Guajira
# 680                                               Huila
# 523                                        Cundinamarca
# 192                                             Bolívar
# 19                                            Antioquia
# 489                                               Chocó
# 527                                        Cundinamarca
# 861                                  Norte de Santander
# 342                                              Caldas
# 627                                             Córdoba
# 341                                              Caldas
# 62                                            Antioquia
# 832                                  Norte de Santander
# 196                                             Bolívar
# 826                                              Nariño
# 576                                        Cundinamarca
# 15                                            Antioquia
# 951                                           Santander
# 785                                              Nariño
# 53                                            Antioquia
# 990                                           Santander
# 310                                              Boyacá
# 361                                              Caldas
# 784                                              Nariño
# 851                                  Norte de Santander
# 259                                              Boyacá
# 376                                             Caquetá
# 223                                              Boyacá
# 412                                               Cauca
# 566                                        Cundinamarca
# 438                                               Cauca
# 156                                           Atlántico
# 172                                             Bolívar
# 228                                              Boyacá
# 1050                                             Tolima
# 888                                             Quindio
# 1010                                              Sucre
# 598                                        Cundinamarca
# 396                                            Casanare
# 1108                                    Valle del Cauca
# 1107                                    Valle del Cauca
# 931                                           Santander
# 271                                              Boyacá
# 925                                           Santander
# 152                                           Atlántico
# 702                                          La Guajira
# 854                                  Norte de Santander
# 885                                             Quindio
# 89                                            Antioquia
# 179                                             Bolívar
# 18                                            Antioquia
# 182                                             Bolívar
# 688                                               Huila
# 896                                           Risaralda
# 768                                              Nariño
# 898                                           Risaralda
# 833                                  Norte de Santander
# 161                                           Atlántico
# 1049                                             Tolima
# 367                                             Caquetá
# 1055                                             Tolima
# 11                                            Antioquia
# 369                                             Caquetá
# 692                                          La Guajira
# 636                                             Córdoba
# 291                                              Boyacá
# 50                                            Antioquia
# 531                                        Cundinamarca
# 462                                               Cesar
# 946                                           Santander
# 208                                             Bolívar
# 71                                            Antioquia
# 257                                              Boyacá
# 929                                           Santander
# 41                                            Antioquia
# 247                                              Boyacá
# 605                                        Cundinamarca
# 232                                              Boyacá
# 115                                           Antioquia
# 1023                                             Tolima
# 512                                        Cundinamarca
# 516                                        Cundinamarca
# 149                                           Atlántico
# 593                                        Cundinamarca
# 338                                              Caldas
# 1041                                             Tolima
# 933                                           Santander
# 244                                              Boyacá
# 233                                              Boyacá
# 212                                             Bolívar
# 568                                        Cundinamarca
# 183                                             Bolívar
# 311                                              Boyacá
# 944                                           Santander
# 240                                              Boyacá
# 141                                              Arauca
# 715                                           Magdalena
# 730                                           Magdalena
# 363                                              Caldas
# 891                                             Quindio
# 339                                              Caldas
# 272                                              Boyacá
# 550                                        Cundinamarca
# 424                                               Cauca
# 96                                            Antioquia
# 22                                            Antioquia
# 333                                              Boyacá
# 491                                               Chocó
# 475                                               Chocó
# 661                                               Huila
# 580                                        Cundinamarca
# 761                                                Meta
# 80                                            Antioquia
# 344                                              Caldas
# 43                                            Antioquia
# 1079                                    Valle del Cauca
# 408                                               Cauca
# 690                                               Huila
# 973                                           Santander
# 143   Archipiélago de San Andrés Providencia y Santa...
# 682                                               Huila
# 246                                              Boyacá
# 791                                              Nariño
# 1038                                             Tolima
# 964                                           Santander
# 930                                           Santander
# 226                                              Boyacá
# 26                                            Antioquia
# 794                                              Nariño
# 1110                                    Valle del Cauca
# 387                                            Casanare
# 353                                              Caldas
# 771                                              Nariño
# 266                                              Boyacá
# 935                                           Santander
# 318                                              Boyacá
# 202                                             Bolívar
# 325                                              Boyacá
# 899                                           Risaralda
# 377                                             Caquetá
# 862                                  Norte de Santander
# 159                                           Atlántico
# 1087                                    Valle del Cauca
# 66                                            Antioquia
# 206                                             Bolívar
# 1089                                    Valle del Cauca
# 221                                              Boyacá
# 1070                                    Valle del Cauca
# 578                                        Cundinamarca
# 994                                           Santander
# 639                                             Córdoba
# 665                                               Huila
# 1024                                             Tolima
# 943                                           Santander
# 12                                            Antioquia
# 913                                           Santander
# 319                                              Boyacá
# 504                                        Cundinamarca
# 328                                              Boyacá
# 267                                              Boyacá
# 982                                           Santander
# 346                                              Caldas
# 666                                               Huila
# 1015                                              Sucre
# 299                                              Boyacá
# 34                                            Antioquia
# 897                                           Risaralda
# 132                                           Antioquia
# 374                                             Caquetá
# 56                                            Antioquia
# 831                                  Norte de Santander
# 603                                        Cundinamarca
# 39                                            Antioquia
# 30                                            Antioquia
# 349                                              Caldas
# 393                                            Casanare
# 1022                                             Tolima
# 846                                  Norte de Santander
# 906                                           Risaralda
# 514                                        Cundinamarca
# 708                                           Magdalena
# 157                                           Atlántico
# 886                                             Quindio
# 255                                              Boyacá
# 1051                                             Tolima
# 495                                               Chocó
# 1100                                    Valle del Cauca
# 868                                  Norte de Santander
# 921                                           Santander
# 849                                  Norte de Santander
# 229                                              Boyacá
# 111                                           Antioquia
# 506                                        Cundinamarca
# 800                                              Nariño
# 518                                        Cundinamarca
# 243                                              Boyacá
# 16                                            Antioquia
# 235                                              Boyacá
# 1030                                             Tolima
# 795                                              Nariño
# 1106                                    Valle del Cauca
# 320                                              Boyacá
# 317                                              Boyacá
# 581                                        Cundinamarca
# 775                                              Nariño
# 556                                        Cundinamarca
# 224                                              Boyacá
# 428                                               Cauca
# 542                                        Cundinamarca
# 631                                             Córdoba
# 40                                            Antioquia
# 571                                        Cundinamarca
# 36                                            Antioquia
# 1099                                    Valle del Cauca
# 439                                               Cauca
# 955                                           Santander
# 138                                              Arauca
# 413                                               Cauca
# 781                                              Nariño
# 521                                        Cundinamarca
# 819                                              Nariño
# 356                                              Caldas
# 770                                              Nariño
# 850                                  Norte de Santander
# 1115                                             Vaupés
# 23                                            Antioquia
# 136                                              Arauca
# 572                                        Cundinamarca
# 1067                                             Tolima
# 586                                        Cundinamarca
# 1008                                              Sucre
# 534                                        Cundinamarca
# 300                                              Boyacá
# 20                                            Antioquia
# 68                                            Antioquia
# 543                                        Cundinamarca
# 752                                                Meta
# 90                                            Antioquia
# 900                                           Risaralda
# 286                                              Boyacá
# 498                                        Cundinamarca
# 621                                             Córdoba
# 254                                              Boyacá
# 1065                                             Tolima
# 664                                               Huila
# 574                                        Cundinamarca
# 617                                             Córdoba
# 1061                                             Tolima
# 589                                        Cundinamarca
# 524                                        Cundinamarca
# 686                                               Huila
# 630                                             Córdoba
# 297                                              Boyacá
# 773                                              Nariño
# 699                                          La Guajira
# 1091                                    Valle del Cauca
# 375                                             Caquetá
# 35                                            Antioquia
# 538                                        Cundinamarca
# 242                                              Boyacá
# 829                                              Nariño
# 28                                            Antioquia
# 634                                             Córdoba
# 988                                           Santander
# 701                                          La Guajira
# 322                                              Boyacá
# 163                                           Atlántico
# 532                                        Cundinamarca
# 32                                            Antioquia
# 283                                              Boyacá
# 869                                  Norte de Santander
# 984                                           Santander
# 422                                               Cauca
# 133                                           Antioquia
# 916                                           Santander
# 830                                  Norte de Santander
# 971                                           Santander
# 1076                                    Valle del Cauca
# 441                                               Cauca
# 282                                              Boyacá
# 817                                              Nariño
# 222                                              Boyacá
# 433                                               Cauca
# 554                                        Cundinamarca
# 844                                  Norte de Santander
# 502                                        Cundinamarca
# 663                                               Huila
# 48                                            Antioquia
# 547                                        Cundinamarca
# 124                                           Antioquia
# 789                                              Nariño
# 460                                               Cesar
# 575                                        Cundinamarca
# 166                                           Atlántico
# 25                                            Antioquia
# 731                                           Magdalena
# 1103                                    Valle del Cauca
# 303                                              Boyacá
# 1095                                    Valle del Cauca
# 908                                           Risaralda
# 144   Archipiélago de San Andrés Providencia y Santa...
# 870                                            Putumayo
# 60                                            Antioquia
# 938                                           Santander
# 251                                              Boyacá
# 779                                              Nariño
# 902                                           Risaralda
# 890                                             Quindio
# 436                                               Cauca
# 315                                              Boyacá
# 1105                                    Valle del Cauca
# 1052                                             Tolima
# 654                                            Guaviare
# 164                                           Atlántico
# 825                                              Nariño
# ...
# 86                          OLAYA               75.639231
# 1032                       COELLO               75.628462
# 853                      PAMPLONA               75.598462
# 21                       APARTADÓ               75.578462
# 903                      MISTRATÓ               75.542308
# 46                      CONCORDIA               75.488462
# 530                    GACHANCIPÁ               75.459231
# 17                    ANGELÓPOLIS               75.446154
# 1056                    RIOBLANCO               75.347692
# 733                    SITIONUEVO               75.296154
# 155                         PIOJÓ               75.261538
# 772                       BUESACO               75.257692
# 814                      RICAURTE               75.168462
# 953                    LA BELLEZA               75.150769
# 822                       SANDONÁ               75.060000
# 1074                 BUENAVENTURA               75.002308
# 207                        SIMITÍ               74.993077
# 505                        BOJACÁ               74.926923
# 567                          PULÍ               74.903846
# 837                       CÁCHIRA               74.822308
# 139                        FORTUL               74.819231
# 276                     PACHAVITA               74.802308
# 948                       GÁMBITA               74.745385
# 1064                       SUÁREZ               74.744615
# 820                     SAN PABLO               74.738462
# 685                         TELLO               74.678462
# 787                         FUNES               74.633077
# 834                       CHITAGÁ               74.630000
# 355                        PÁCORA               74.615385
# 57                       FREDONIA               74.561538
# 249                      FLORESTA               74.558462
# 140                 PUERTO RONDÓN               74.551538
# 118                        TARAZÁ               74.547692
# 14                          AMAGÁ               74.477692
# 803                       MALLAMA               74.455385
# 294              SAN JOSÉ DE PARE               74.440000
# 641                        TUCHÍN               74.432605
# 1072                      ARGELIA               74.424615
# 941                       FLORIÁN               74.416923
# 548                       LA PEÑA               74.396923
# 629                  PUEBLO NUEVO               74.365385
# 965                        ONZAGA               74.341538
# 1101                      SEVILLA               74.336154
# 287                       QUÍPAMA               74.297692
# 170             ALTOS DEL ROSARIO               74.270769
# 1102                         TORO               74.199231
# 563                         PANDI               74.107692
# 909                        AGUADA               74.106923
# 280                         PAUNA               73.801538
# 366        BELÉN DE LOS ANDAQUÍES               73.691538
# 843                     GRAMALOTE               73.668462
# 591                          TENA               73.630769
# 600                           UNE               73.600769
# 262                   LA VICTORIA               73.554615
# 199         SAN JACINTO DEL CAUCA               73.453077
# 872                         ORITO               73.386154
# 91                    PUERTO NARE               73.346923
# 1066                    VENADILLO               73.303077
# 103        SAN JOSÉ DE LA MONTAÑA               73.290769
# 313                     SOTAQUIRÁ               73.148462
# 724                   PUEBLOVIEJO               73.128462
# 478           EL CARMEN DE ATRATO               73.116154
# 827                        TANGUA               73.083846
# 961                    MOLAGAVITA               73.062308
# 509                     CAPARRAPÍ               73.041538
# 864                       TEORAMA               72.987692
# 419                       MIRANDA               72.926923
# 354                   PENSILVANIA               72.860769
# 760             SAN JUAN DE ARAMA               72.707692
# 384                     LA SALINA               72.668462
# 358                      SALAMINA               72.612308
# 693                     BARRANCAS               72.470769
# 595                       TOCAIMA               72.465385
# 954                        LA PAZ               72.410000
# 472                    BAJO BAUDÓ               72.368462
# 360                      SAN JOSÉ               72.361538
# 529                       GACHALÁ               72.315385
# 536                       GUADUAS               72.297692
# 87                          PEQUE               72.276154
# 694                       DIBULLA               72.203077
# 411                      GUACHENÉ               72.173846
# 440                        TOTORÓ               72.137692
# 725                      REMOLINO               72.106154
# 696                     EL MOLINO               72.043846
# 602                       VERGARA               72.002308
# 980           SAN JOSÉ DE MIRANDA               71.998462
# 815                 ROBERTO PAYÁN               71.955385
# 162                   SANTA LUCÍA               71.797692
# 644                      CACAHUAL               71.757665
# 404                  BUENOS AIRES               71.660769
# 585                        SUESCA               71.658462
# 248                    FIRAVITOBA               71.649231
# 173                   ARROYOHONDO               71.634615
# 610                       ZIPACÓN               71.621538
# 429                         ROSAS               71.530000
# 264                       MACANAL               71.514615
# 623                  LOS CÓRDOBAS               71.385385
# 127                    VALPARAÍSO               71.233077
# 594                      TIBIRITA               71.171538
# 321                      TIBASOSA               71.162308
# 848                      LABATECA               71.149231
# 673                       OPORAPA               71.137692
# 612                         ÚTICA               71.083846
# 755                 PUERTO LLERAS               71.051538
# 932                      COROMORO               70.976923
# 856                    RAGONVALIA               70.970769
# 806                 OLAYA HERRERA               70.923077
# 167                      USIACURÍ               70.858462
# 298           SAN PABLO DE BORBUR               70.783846
# 236                      CHÍQUIZA               70.755385
# 867                    VILLA CARO               70.699231
# 1118                 LA PRIMAVERA               70.626154
# 427                        PURACÉ               70.384615
# 927                       CHIPATÁ               70.367692
# 219                        BERBEO               70.218462
# 373                         MILÁN               70.170769
# 126                      VALDIVIA               70.110000
# 125                         URRAO               69.899231
# 347                    MANZANARES               69.876923
# 934          EL CARMEN DE CHUCURÍ               69.727692
# 493                          SIPÍ               69.726923
# 265                        MARIPÍ               69.670000
# 402                        BALBOA               69.670000
# 484                   MEDIO BAUDÓ               69.658462
# 63                         GUARNE               69.642308
# 553                         MANTA               69.523846
# 807                        OSPINA               69.496923
# 477       EL CANTÓN DEL SAN PABLO               69.252308
# 205                    SANTA ROSA               69.123077
# 418                    MERCADERES               69.084615
# 263                LABRANZAGRANDE               68.706154
# 936                      EL PEÑÓN               68.703077
# 137                     ARAUQUITA               68.596923
# 496            UNIÓN PANAMERICANA               68.558462
# 1116                     YAVARATÉ               68.472308
# 881             VALLE DEL GUAMUEZ               68.237692
# 197                  SAN FERNANDO               67.956923
# 659                      ALTAMIRA               67.802308
# 335                     VIRACACHÁ               67.802308
# 351                         NEIRA               67.790000
# 544                         JUNÍN               67.777692
# 24                        ARMENIA               67.776154
# 858                   SAN CALIXTO               67.723077
# 1048                      MURILLO               67.610769
# 657                          AIPE               67.563846
# 698                     HATONUEVO               67.482308
# 875                 PUERTO GUZMÁN               67.306154
# 969                      PINCHOTE               67.236923
# 65                    GÓMEZ PLATA               67.226154
# 372                  LA MONTAÑITA               67.217692
# 316                     SUTATENZA               67.146923
# 821          SAN PEDRO DE CARTAGO               66.946154
# 365                       ALBANIA               66.866154
# 382                       CHÁMEZA               66.851538
# 485                MEDIO SAN JUAN               66.846923
# 796                    LA LLANADA               66.680769
# 823                 SANTA BÁRBARA               66.644615
# 558                          NILO               66.390000
# 490                       RÍO IRÓ               66.252308
# 507                      CACHIPAY               66.000769
# 8                   PUERTO NARIÑO               65.949231
# 453                      GONZÁLEZ               65.661538
# 275                       OTANCHE               65.615385
# 220                     BETÉITIVA               65.510769
# 877                 SAN FRANCISCO               65.456923
# 131                          YALÍ               65.302308
# 274                        OICATÁ               64.870769
# 452                       GAMARRA               64.822308
# 895                          APÍA               64.594615
# 811                   PROVIDENCIA               64.349973
# 120                      TITIRIBÍ               64.347692
# 874                PUERTO CAICEDO               64.323077
# 1117                     CUMARIBO               64.303077
# 651                       CALAMAR               64.234615
# 805                        NARIÑO               64.086923
# 400                      ALMAGUER               64.044615
# 119                         TARSO               63.926923
# 777             CUASPUD CARLOSAMA               63.876154
# 1081                     EL CAIRO               63.820769
# 660                        BARAYA               63.810000
# 918                       CABRERA               63.526154
# 878                    SAN MIGUEL               63.486154
# 469                        ATRATO               63.401538
# 314                       SUSACÓN               63.345385
# 2                      LA PEDRERA               63.260000
# 662                      COLOMBIA               63.227692
# 511                      CHAGUANÍ               63.196154
# 763                         URIBE               63.133846
# 947                       GUAVATÁ               62.915385
# 757                   PUERTO RICO               62.783846
# 910                       ALBANIA               62.711538
# 1112                         MITÚ               62.435385
# 479       EL LITORAL DEL SAN JUAN               62.207692
# 270                      MOTAVITA               62.098462
# 824                     SANTACRUZ               62.025357
# 1093                       OBANDO               61.970000
# 799                         LEIVA               61.740769
# 977                    SAN BENITO               61.723077
# 486                         NUQUÍ               61.507692
# 695                   DISTRACCIÓN               61.492308
# 705                       URUMITA               61.436154
# 879                      SANTIAGO               61.364615
# 189                   MONTECRISTO               61.224615
# 1111                       CARURÚ               61.185385
# 797                       LA TOLA               61.151538
# 380                    VALPARAÍSO               61.118462
# 337                        ÚMBITA               61.095385
# 6                  PUERTO ALEGRÍA               61.050594
# 753              PUERTO CONCORDIA               60.805385
# 227                  CAMPOHERMOSO               60.746154
# 83                         NARIÑO               60.668462
# 468                    ALTO BAUDÓ               60.564615
# 650                    SAN FELIPE               60.213077
# 816                     SAMANIEGO               60.175385
# 646                  LA GUADALUPE               60.106154
# 171                        ARENAL               59.823077
# 966                        PALMAR               59.476923
# 10                       TARAPACÁ               59.426923
# 751                     MAPIRIPÁN               59.192308
# 370                     EL PAUJÍL               58.845385
# 1114                    PAPUNAHUA               58.826720
# 435                         SUCRE               58.606154
# 430                 SAN SEBASTIÁN               58.058462
# 350                     MARULANDA               57.822308
# 483                  MEDIO ATRATO               57.258286
# 431                    SANTA ROSA               57.113846
# 476                      CÉRTEGUI               56.960000
# 1069                       ALCALÁ               56.711538
# 241                        CUBARÁ               56.596923
# 1025                   ANZOÁTEGUI               56.574615
# 3                     LA VICTORIA               56.555803
# 7                    PUERTO ARICA               56.100000
# 992                         VETAS               55.952308
# 394                        SÁCAMA               55.824615
# 559                       NIMAIMA               55.759231
# 378                        SOLANO               55.610000
# 194                     RÍO VIEJO               55.087841
# 801                     LOS ANDES               54.356923
# 1                     LA CHORRERA               53.954615
# 193                       REGIDOR               53.413846
# 783                    EL ROSARIO               53.116923
# 9                PUERTO SANTANDER               52.803846
# 776                     CONTADERO               52.663077
# 766                         ALBÁN               52.101538
# 652                    EL RETORNO               51.958462
# 434            SOTARÁ - PAISPAMBA               51.639231
# 391                       RECETOR               50.266599
# 648                     PANA PANA               49.615357
# 749                   LA MACARENA               49.397692
# 818                  SAN BERNARDO               48.949231
# 290                       RÁQUIRA               48.709231
# 1113                        PACOA               48.410769
# 225                      BUSBANZÁ               48.167692
# 649               PUERTO COLOMBIA               47.595533
# 804                      MOSQUERA               47.436923
# 587                          SUSA               47.430769
# 256           GÜICÁN DE LA SIERRA               47.218462
# 234                       CHIVATÁ               47.168462
# 845                        HERRÁN               46.453846
# 786             FRANCISCO PIZARRO               45.780000
# 5                 MIRITÍ - PARANÁ               45.546923
# 0                      EL ENCANTO               45.423374
# 802                         MAGÜÍ               43.251538
# 647                      MORICHAL               42.401538
# 416                       LA VEGA               41.630769
# 653                    MIRAFLORES               34.143077

# %% [markdown]
# #### Rendimiento educativo por municipio

# %%
rendimiento = hechos_nombres.groupby(['departamento', 'municipio'])[
    ['repitencia', 'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media']
].mean().reset_index()

# %%
rendimiento['rendimiento_promedio'] = rendimiento[
    ['repitencia', 'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media']
].mean(axis=1)

# %% [markdown]
# *Departamentos con mejor cobertura*

# %%
mejor_cobertura = hechos_nombres.groupby('departamento')['cobertura_neta'].mean().sort_values(ascending=False)

# %%
# !pip install pandasql
# Out:
# Requirement already satisfied: pandasql in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (0.7.3)
# Requirement already satisfied: numpy in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandasql) (2.3.1)
# Requirement already satisfied: pandas in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandasql) (2.3.0)
# Requirement already satisfied: sqlalchemy in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandasql) (2.0.41)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from sqlalchemy->pandasql) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\usuario\miniconda3\envs\diplomado_usta\lib\site-packages (from sqlalchemy->pandasql) (4.14.0)

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

query = """
SELECT departamento, AVG(cobertura_neta) AS cobertura_promedio
FROM hechos_nombres
GROUP BY departamento
ORDER BY cobertura_promedio DESC
"""

resultado = pysqldf(query)
print(resultado)
# Out:
#                                          departamento  cobertura_promedio
# 0                                             Quindio           94.579615
# 1                                               Sucre           93.849172
# 2                                               Cesar           93.730656
# 3                                           Magdalena           93.263854
# 4                                                Meta           90.630439
# 5                                           Bogotá DC           89.493077
# 6                                              Tolima           89.239083
# 7                                        Cundinamarca           88.541257
# 8                                            Casanare           88.517623
# 9                                           Antioquia           88.095366
# 10                                            Córdoba           88.032417
# 11                                          Atlántico           87.567434
# 12                                            Bolívar           87.470434
# 13                                          Santander           87.076041
# 14                                              Huila           86.456154
# 15                                          Risaralda           86.099121
# 16                                             Boyacá           84.536768
# 17                                             Caldas           84.112707
# 18                                 Norte de Santander           83.671218
# 19                                    Valle del Cauca           83.251593
# 20                                             Arauca           82.408791
# 21  Archipiélago de San Andrés Providencia y Santa...           82.218462
# 22                                         La Guajira           81.725846
# 23                                              Chocó           80.882185
# 24                                           Putumayo           80.870038
# 25                                            Vichada           80.674038
# 26                                              Cauca           79.544187
# 27                                             Nariño           78.062703
# 28                                            Caquetá           77.631587
# 29                                            Guainía           65.388304
# 30                                           Amazonas           63.411851
# 31                                           Guaviare           62.180061
# 32                                             Vaupés           59.806312
# 33                                           NACIONAL            0.920733
